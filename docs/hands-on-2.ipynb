# %% [markdown]
# # Analog: Ana(lyzing) Log(s)
#
# I wrote [analog](https://github.com/apparebit/analog) to scratch an itch,
# analyzing the access logs for my personal website
# [apparebit.com](https://apparebit.com). This notebook chronicles the first
# several forays into the data. But the presentation is idealized, since notebook
# and analog both changed quite a bit as a result of these forays.

# %% [markdown]
# ## 1. Preliminaries
#
# We get started by importing analog.

# %%
import sys
sys.path.insert(0, '..')

import konsole
konsole.config(level=konsole.DEBUG)

# import analog
import os
import os.path
import sys

import numpy as np
import pandas as pd

# Make package accessible by injecting repository root into Python package path
root, docs = os.path.split(os.getcwd())
assert docs == 'docs' and os.path.basename(root) == 'analog'
sys.path.insert(0, root)
os.chdir(root)

import analog
# Out:
# [INFO] Note: NumExpr detected 20 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [INFO] NumExpr defaulting to 8 threads.
# [DEBUG] matplotlib data path: /Users/rgrimm/Work/analog/.venv/lib/python3.11/site-packages/matplotlib/mpl-data.
# [DEBUG] CONFIGDIR=/Users/rgrimm/.matplotlib.
# [DEBUG] interactive is False.
# [DEBUG] platform is darwin.

# %% [markdown]
# ### 1.1 The Log Data
#
# Next, we load the log data. `analog.latest()` parses, enriches, and combines
# monthly logs as needed. `analog.validate()` checks that the dataframe has the
# expected columns with the expected types, does not contain null values in
# non-null columns, and that columns with correlated null values in fact observe
# those correlations.

# %%
df = analog.latest(os.path.join(root, 'data'))
df.info(verbose=True, memory_usage=True)
analog.validate(df)
# Out:
# [INFO] Load existing log frame '/Users/rgrimm/Work/analog/data/apparebit.com-2018-07-2023-06.parquet'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310648 entries, 0 to 310647
# Data columns (total 35 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   client_address     310648 non-null  string
#  1   timestamp          310648 non-null  datetime64[ns, UTC]
#  2   method             310648 non-null  category
#  3   path               310648 non-null  string
#  4   query              5140 non-null    string
#  5   fragment           0 non-null       string
#  6   protocol           310648 non-null  category
#  7   status             310648 non-null  int16
#  8   size               310648 non-null  int32
#  9   referrer           135151 non-null  string
#  10  user_agent         306800 non-null  string
#  11  server_name        285613 non-null  string
#  12  server_address     285613 non-null  string
#  13  cool_path          310648 non-null  string
#  14  content_type       310648 non-null  category
#  15  status_class       310648 non-null  category
#  16  referrer_scheme    130439 non-null  category
#  17  referrer_host      130439 non-null  string
#  18  referrer_path      124771 non-null  string
#  19  referrer_query     20637 non-null   string
#  20  referrer_fragment  16 non-null      string
#  21  client_name        228292 non-null  string
#  22  client_latitude    310612 non-null  float64
#  23  client_longitude   310612 non-null  float64
#  24  client_city        187795 non-null  string
#  25  client_country     310610 non-null  string
#  26  agent_family       306800 non-null  object
#  27  agent_version      306800 non-null  object
#  28  os_family          306800 non-null  object
#  29  os_version         306800 non-null  object
#  30  device_family      306800 non-null  object
#  31  device_brand       306800 non-null  object
#  32  device_model       306800 non-null  object
#  33  is_bot1            310648 non-null  bool
#  34  is_bot2            310648 non-null  bool
# dtypes: bool(2), category(5), datetime64[ns, UTC](1), float64(2), int16(1), int32(1), object(7), string(16)
# memory usage: 65.5+ MB

# %% [markdown]
# The 36 columns listed above comprise three kinds of data:
#
#   * `client_address` through `server_address` are parsed from access log;
#   * `content_type` through `status_class` are derived from primary data;
#   * `client_name` through `is_bot2` are extracted from databases.

# %% [markdown]
# ### 1.2 Two Sources of Truth for Bots
#
# Analog uses two different projects' regular expressions for classifying user
# agents as bots:
#
#  1. `agent_family` through `is_bot` are filled in with
#     [ua-parser](https://github.com/ua-parser).
#  2. `bot_category` and `is_bot2` are filled in with
#     [matomo](https://github.com/matomo-org/device-detector).
#
# We need both:

# %%
def requests_per_agent(label, data):
    with analog.fresh_counts() as rows:
        data.count_rows().unique_values('user_agent').count_rows()
        print(f'{label:<20}: {rows[0]:7,} requests from {rows[1]:5,} user agents')

log = analog.analyze(df)
requests_per_agent('all requests', log)
requests_per_agent('ua-parser or matomo', log.only.bots())
requests_per_agent('ua-parser only', log.only.equals('is_bot1', True))
requests_per_agent('matomo only', log.only.equals('is_bot2', True))
# Out:
# all requests        : 310,648 requests from 8,866 user agents
# ua-parser or matomo : 108,036 requests from 3,341 user agents
# ua-parser only      :  89,163 requests from   538 user agents
# matomo only         :  87,738 requests from 3,261 user agents

# %% [markdown]
# A more detailed comparison of the two classifications revealed a minor bug in
# `ua-parser`'s classification. Analog corrects that bug while enriching the
# parsed access logs.

# %% [markdown]
# ## 2. Page Views
#
# [apparebit.com](https://apparebit.com) utilizes commercially licensed fonts. The
# license terms impose an upper limit of monthly page views. Hence, I'm eager to
# check them first:

# %%
page_views = (
    analog.analyze(df)  # A page view
    .only.successful()  # is a successful
    .only.GET()         # GET request
    .only.markup()      # for markup (HTML)
    .only.humans()      # made by humans.
)

# %% [markdown]
# ### 2.1 Monthly Page Views
#
# So how many page views were there for each month? Not enough to require purchase
# of the next license tier. Yay!

# %%
konsole.config(level=konsole.INFO) # Unless you want to wade through hundreds of findfont log entries...
page_views.monthly.requests().plot(figsize=(8,5)).done()

# %% [markdown]
# ### 2.2 Top 10 Most Popular Pages Last Month
#
# Ooh, I love how traffic increased in early 2021. But what pages drew the most
# visitors? Let's check the top 10 most popular pages for the last month:

# %%
page_views.over.last_month().value_counts("cool_path").show(rows=10).done()
# Out:
#                                 count
# cool_path
# /                                 442
# /blog/2019/i-feel-love            268
# /blog/2022/wrong-impression       107
# /blog                              33
# /about/apparebit                   25
# /features/breath                   22
# /about/privacy                     21
# /features/candy-or-bust/voyeur     21
# /about/robert-grimm                20
# /about/robert-grimm/with-halo      18

# %% [markdown]
# ### 2.3 Top 10 Most Popular Pages Last Year
#
# Hmm, interesting. What were the 10 most popular pages for the last year?

# %%
page_views.over.last_year().value_counts("cool_path").show(rows=10).done()
# Out:
#                                 count
# cool_path
# /                                3018
# /blog/2019/i-feel-love           1332
# /blog/2022/wrong-impression       733
# /blog                             244
# /about/apparebit                  213
# /about/robert-grimm               171
# /about/privacy                    141
# /about/robert-grimm/with-halo     100
# /features/candy-or-bust/voyeur     96
# /features/candy-or-bust            96

# %% [markdown]
# ### 2.4 Domain Names for the Win!
#
# It sure makes sense that my home page is #1. I also expected the blog index to
# be popular. But I didn't expect the blog posts [Game of Thrones, US
# Edition](https://apparebit.com/blog/2021/game-of-thrones) and [I Feel
# Love](https://apparebit.com/blog/2019/i-feel-love) to be that popular.
#
# Come to think of it, the two pages do share one trait that separates them from
# all other posts: I own two other domains, [deface.info](http://deface.info) and
# [obscenely.gay](http://obscenely.gay), that just happen to redirect to them. At
# the same time, I haven't advertised the two secondary domains beyond mentioning
# them on Twitter. So do these secondary domains make a difference?
#
# The thing is: It's pretty much impossible to prove or disprove whether the
# secondary domains boost traffic based on the log data. In theory, the `Referer`
# (sic) header would provide us with just the information we need. But in
# practice, the two domain registrars providing URL forwarding for the domains
# (understandably) do not go through the trouble of maintaining TLS certificates
# for them. As a result, a browser accessing either domain necessarily starts out
# using insecure HTTP and, since <apparebit.com> only supports HTTPS, ends up with
# secure HTTPS. But according to the latest default referrer policy,
# `strict-origin-when-cross-origin`, clients should *not* include the `Referer`
# for requests with no or mixed security.
#
# Let's check the data for *I Feel Love*:

# %%
def domain_to_path(data, domain, path):
    with analog.fresh_counts() as counts:
        referrers = (
            data
            .only.equals('cool_path', path)
            .over.last_year()
            .count_rows()
            .value_counts('referrer_host')
            .show()
            .data
        )

    requests = pd.Series([
        counts[0] - referrers.sum(), # No referrer
        referrers.get('www.google.com', 0),
        referrers.get(domain, 0) + referrers.get(f'www.{domain}', 0),
        counts[0]
    ], ['no_referrer', 'google', domain, 'page_views']).rename('requests')
    percentages = (requests * 100 / counts[0]).round(1).rename('percent')
    return analog.merge(requests, percentages)

domain_to_path(page_views, 'obscenely.gay', '/blog/2019/i-feel-love')
# Out:
#                            count
# referrer_host
# obscenely.gay                436
# www.google.com                77
# www.obscenely.gay             73
# obscenely.gay:80              19
# obscenely.gay:443             17
# apparebit.com                 15
# blog.obscenely.gay            13
# obscenely.gay.                11
# wordpress.obscenely.gay        6
# test.obscenely.gay             5
# demo.obscenely.gay             4
# glpi.obscenely.gay             3
# tlink.lib.tsinghua.edu.cn      3
# bilancompetences.pro           2
# wp.obscenely.gay               2
# 2023.obscenely.gay             2
# lionna.ru                      1
# www.google.com.hk              1
# www.apparebit.com              1
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>requests</th>
#       <th>percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>no_referrer</th>
#       <td>641</td>
#       <td>48.1</td>
#     </tr>
#     <tr>
#       <th>google</th>
#       <td>77</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>obscenely.gay</th>
#       <td>509</td>
#       <td>38.2</td>
#     </tr>
#     <tr>
#       <th>page_views</th>
#       <td>1332</td>
#       <td>100.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Just as predicted, a large number of requests, 50.4%, do not include a referrer,
# while only small number, 8.1%, can be attributed to `obscenely.gay`. At 36.8% of
# all requests, Google turns out to be an important source of traffic — for this
# page.
#
# Two comments about the code above:
#
#   1. Analog augments but not replaces Pandas. More complicated analysis, like
#      the one above, may just require falling back onto Pandas.
#   2. It often pays off to define a function when performing non-trivial
#      analysis. Chances are we'll be able to reuse it.
#
# In fact, let's reuse the above function right now:

# %%
domain_to_path(page_views, 'deface.info', '/blog/2022/wrong-impression')
# Out:
#                    count
# referrer_host
# deface.info          165
# www.deface.info       38
# apparebit.com         35
# www.google.com        25
# l.facebook.com         4
# m.facebook.com         3
# baidu.com              3
# t.co                   3
# google.com             2
# www.apparebit.com      1
# talt.one               1
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>requests</th>
#       <th>percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>no_referrer</th>
#       <td>453</td>
#       <td>61.8</td>
#     </tr>
#     <tr>
#       <th>google</th>
#       <td>25</td>
#       <td>3.4</td>
#     </tr>
#     <tr>
#       <th>deface.info</th>
#       <td>203</td>
#       <td>27.7</td>
#     </tr>
#     <tr>
#       <th>page_views</th>
#       <td>733</td>
#       <td>100.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# At 69.1%, the lack of referrers is even more pronounced for *Game of Thrones, US
# Edition*, whereas the percentage of referrals from the secondary domain is
# almost double, though still quite small.
#
# #### Lesson Learned
#
# While I cannot prove that the secondary domains serve as traffic boosters, that
# still seems like the simplest explanation. Hence, I'm inclined to believe it
# anyways. That belief then leads me to the following rule for maximizing the
# domains' impact:
#
# > Make sure to point `obscenely.gay` at my gayest page and `deface.info` at the
# > page that is most damning for Facebook!
#
# As of this writing, the latter is [Wrong
# Impression](https://apparebit.com/blog/2022/wrong-impression), which presents
# compelling evidence that Facebook is cooking the books and hence misrepresenting
# its business to paying customers, investors, and regulators alike. I've updated
# `deface.info` accordingly.

# %% [markdown]
# ## 3. Status Codes
#
# Let switch gears a bit: So far, we considered only successful GET requests for
# markup by humans, i.e., page views. Now, we are going to consider all requests
# and the resulting response status codes.
#
#
# ### 3.1 The Four Status Classes
#
# HTTP status codes come in hundreds and distinguish between:
#
#   * 2xx: successful requests,
#   * 3xx: redirections,
#   * 4xx: client errors,
#   * 5xx: server errors.
#
# Let's look at these four status classes on a monthly basis:

# %%
request_status = (
    analog.analyze(df)
    .monthly.status_classes()
    .plot(kind='bar', stacked=True, width=0.8, figsize=(12,7), color=[
        '#6d7278', '#00a513', '#b0f566', '#bf0016', '#fdafc0'
    ])
)

data = request_status.data
axes = request_status.axes
figure = axes.get_figure()

figure.set_facecolor('#f0f2f5')
axes.set_facecolor('#f0f2f5')

yticks = axes.get_yticks().tolist()
# Next line silences warning (https://stackoverflow.com/questions/63723514
# /userwarning-fixedformatter-should-only-be-used-together-with-fixedlocator)
axes.yaxis.set_ticks(yticks)
axes.yaxis.set_ticklabels(['{:,}'.format(int(x)) for x in yticks])

def year_month_labels(year_months, axes):
    labels = []
    current_year = None
    for year, month in year_months:
        labels.append(f'{year}-{month:02}' if year != current_year else f'{month:02}')
        current_year = year
    axes.set_xticks([*range(len(year_months))])
    axes.set_xticklabels(labels, rotation=90)

year_month_labels(data.index.tolist(), axes)

# %% [markdown]
# Sweet! That's a nice graph. Admittedly, it took some futzing with plot size and
# column `width` because the defaults made for too small a graph with too much
# space between columns. But adjusting the plot was easy, since analog passes
# keyword arguments through to Pandas' `plot()` method.

# %%
error_percent = (data['CLIENT_ERROR'] + data['SERVER_ERROR']) / data.sum(axis=1) * 100
axes = error_percent.plot(kind='bar', width=0.8, figsize=(12,7), color=['#bf0016'])
figure = axes.get_figure()

figure.set_facecolor('#f0f2f5')
axes.set_facecolor('#f0f2f5')

yticks = axes.get_yticks().tolist()
# Next line silences warning (https://stackoverflow.com/questions/63723514
# /userwarning-fixedformatter-should-only-be-used-together-with-fixedlocator)
axes.yaxis.set_ticks(yticks)
axes.yaxis.set_ticklabels([f'{x:.0f}%' for x in yticks])


year_month_labels(error_percent.index, axes)

# %% [markdown]
# ### 3.2 Top 10 Paths Resulting in Server Errors
#
# The presence of server errors is a bit surprising. It suggests that my hosting
# provider's shared server instance isn't particularly well managed, at least from
# June 2021 through June 2022. That's no good. But before calling their customer
# service, we should find out a little more about those server errors:

# %%
(
    analog.analyze(df)
    .over.range(*analog.monthly_period('2021-06', '2022-06'))
    .only.server_error()
    .value_counts('path')
    [:10]
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>path</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>/blog/2021/game-of-thrones/wp1/wp-includes/wlw...</th>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>/blog/2021/game-of-thrones/wp/wp-includes/wlwm...</th>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>/blog/2021/game-of-thrones/wordpress/wp-includ...</th>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>/blog/2021/game-of-thrones/web/wp-includes/wlw...</th>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>/blog/2021/game-of-thrones/cms/wp-includes/wlw...</th>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>/blog/2021/game-of-thrones/test/wp-includes/wl...</th>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>/blog/2021/game-of-thrones/site/wp-includes/wl...</th>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>/blog/2021/game-of-thrones/blog/wp-includes/wl...</th>
#       <td>151</td>
#     </tr>
#     <tr>
#       <th>/blog/2021/game-of-thrones/shop/wp-includes/wl...</th>
#       <td>149</td>
#     </tr>
#     <tr>
#       <th>/blog/2021/game-of-thrones/2019/wp-includes/wl...</th>
#       <td>149</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Ah, WordPress! I'm guessing that the shared server is somehow misconfigured and
# fails on these probes for WordPress security vulnerabilities. Personally, I'm
# glad I'm not using a content management system, but instead rely on [my own
# static website generator](https://github.com/apparebit/siteforge) instead.
#
# **About HTML tables**: The code cell above chops off rows beyond the 10th one
# but does not print the wrapped series — instead letting the wrapped series
# become the cell's value. Since all fluent wrappers implement the `_repr_html_()`
# method, IPython automatically formats the data with that method. In contrast,
# analog's fluent `.print()` method needs to work a tad harder to also emit an
# HTML table when inside IPython. In fact, if you go back to the referrer counts,
# you'll find that the same cell prints one dataframe and finishes with another
# dataframe.

# %% [markdown]
# ### 3.3 Analysis of Client Errors
#
# While we are at it, let's look at client errors, too:

# %%
from IPython.display import display, HTML
from analog.ipaddr import resolve_to_countries

client_errors = analog.analyze(df).over.last_year().only.client_error()

display(HTML('<strong>Breakdown by status code</strong>'))
display(client_errors.value_counts('status'))

display(HTML('<strong>Breakdown by path (top 20)</strong>'))
display(client_errors.value_counts('path')[:20])

display(HTML('<strong>Breakdown by client_address (top 20)</strong>'))
addresses = client_errors.value_counts('client_address')[:20].data
localized_addresses = (
    pd.DataFrame(
        resolve_to_countries(addresses.index),
        columns=['client_address', 'country'],
    )
    .join(addresses, on='client_address', how='inner')
)
display(localized_addresses)

display(HTML('<strong>First 20 client errors for Home Page</strong>'))
display(client_errors.only.equals('path', '/')[:20])

display(HTML('<strong>First 20 client errors for I Feel Love</strong>'))
display(client_errors.only.equals('path', '/blog/2019/i-feel-love')[:20])

display(HTML('<strong>First 20 client errors for Bely Display</strong>'))
display(client_errors.only.equals('path', '/assets/fonts/bely-display.woff2')[:20])

display(HTML('<strong>First 20 client errors for non-existent ads.txt</strong>'))
display(client_errors.only.equals('path', '/ads.txt')[:20])
# Out:
# <strong>Breakdown by status code</strong>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>status</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>404</th>
#       <td>6624</td>
#     </tr>
#     <tr>
#       <th>406</th>
#       <td>4381</td>
#     </tr>
#     <tr>
#       <th>403</th>
#       <td>1068</td>
#     </tr>
#     <tr>
#       <th>409</th>
#       <td>373</td>
#     </tr>
#     <tr>
#       <th>421</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>405</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <strong>Breakdown by path (top 20)</strong>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>path</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>/blog/2019/i-feel-love</th>
#       <td>452</td>
#     </tr>
#     <tr>
#       <th>/favicon.ico</th>
#       <td>392</td>
#     </tr>
#     <tr>
#       <th>/ads.txt</th>
#       <td>350</td>
#     </tr>
#     <tr>
#       <th>/</th>
#       <td>287</td>
#     </tr>
#     <tr>
#       <th>/assets/fonts/bely-regular.woff2</th>
#       <td>227</td>
#     </tr>
#     <tr>
#       <th>/wp-login.php</th>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>/th1s_1s_a_4o4.html</th>
#       <td>181</td>
#     </tr>
#     <tr>
#       <th>/robots.txt</th>
#       <td>180</td>
#     </tr>
#     <tr>
#       <th>/e/data/js/ajax.js</th>
#       <td>164</td>
#     </tr>
#     <tr>
#       <th>/index.php</th>
#       <td>160</td>
#     </tr>
#     <tr>
#       <th>/assets/fonts/bely-display.woff2</th>
#       <td>160</td>
#     </tr>
#     <tr>
#       <th>/data/admin/allowurl.txt</th>
#       <td>157</td>
#     </tr>
#     <tr>
#       <th>/assets/fonts/reforma-2018-gris.woff2</th>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>//xmlrpc.php</th>
#       <td>131</td>
#     </tr>
#     <tr>
#       <th>//site/wp-includes/wlwmanifest.xml</th>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>//wp1/wp-includes/wlwmanifest.xml</th>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>//test/wp-includes/wlwmanifest.xml</th>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>//cms/wp-includes/wlwmanifest.xml</th>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>//shop/wp-includes/wlwmanifest.xml</th>
#       <td>129</td>
#     </tr>
#     <tr>
#       <th>/css/album.css</th>
#       <td>128</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <strong>Breakdown by client_address (top 20)</strong>
#      client_address                                            country  count
# 0       178.62.2.74  United Kingdom of Great Britain and Northern I...    232
# 1    163.172.255.57                                             France    223
# 2   217.182.193.103                                             France    222
# 3     45.141.215.69                                             Poland    210
# 4      162.55.86.62                                            Germany    180
# 5     198.20.67.200                           United States of America    170
# 6     184.154.76.34                           United States of America    155
# 7    138.199.60.187                                          Singapore    138
# 8        31.220.1.7                                            Germany    124
# 9     20.125.148.84                           United States of America    105
# 10    45.138.16.242                                             Poland    105
# 11    45.80.158.224                                        Netherlands    105
# 12   185.241.208.73                                             Poland    105
# 13     45.138.16.74                                             Poland    105
# 14     51.254.18.88                                             France    105
# 15    45.138.16.199                                             Poland    105
# 16    92.205.59.185                                             France     93
# 17   194.169.175.71                                        Netherlands     92
# 18    184.154.139.7                           United States of America     84
# 19    27.75.104.191                                           Viet Nam     80
# <strong>First 20 client errors for Home Page</strong>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>client_address</th>
#       <th>timestamp</th>
#       <th>method</th>
#       <th>path</th>
#       <th>query</th>
#       <th>fragment</th>
#       <th>protocol</th>
#       <th>status</th>
#       <th>size</th>
#       <th>referrer</th>
#       <th>...</th>
#       <th>client_country</th>
#       <th>agent_family</th>
#       <th>agent_version</th>
#       <th>os_family</th>
#       <th>os_version</th>
#       <th>device_family</th>
#       <th>device_brand</th>
#       <th>device_model</th>
#       <th>is_bot1</th>
#       <th>is_bot2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>268755</th>
#       <td>114.119.133.120</td>
#       <td>2023-01-01 07:41:03+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>https://wiki.jacob.chvatal.com/pages/ricing</td>
#       <td>...</td>
#       <td>SG</td>
#       <td>PetalBot</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Smartphone</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>268774</th>
#       <td>162.55.86.62</td>
#       <td>2023-01-01 10:52:39+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>DE</td>
#       <td>BLEXBot</td>
#       <td>1.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>268844</th>
#       <td>162.55.86.62</td>
#       <td>2023-01-01 22:44:13+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>DE</td>
#       <td>BLEXBot</td>
#       <td>1.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>269035</th>
#       <td>165.22.199.14</td>
#       <td>2023-01-02 18:02:44+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>NL</td>
#       <td>AhrefsBot</td>
#       <td>7.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>269217</th>
#       <td>162.55.86.62</td>
#       <td>2023-01-03 19:35:37+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>DE</td>
#       <td>BLEXBot</td>
#       <td>1.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>270162</th>
#       <td>114.119.138.207</td>
#       <td>2023-01-06 18:08:43+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>https://131.180.119.44/profile/iwaco-2020/robe...</td>
#       <td>...</td>
#       <td>SG</td>
#       <td>PetalBot</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Smartphone</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>270400</th>
#       <td>162.55.86.62</td>
#       <td>2023-01-08 00:45:40+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>DE</td>
#       <td>BLEXBot</td>
#       <td>1.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>270623</th>
#       <td>162.243.185.35</td>
#       <td>2023-01-09 01:05:51+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.0</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>273233</th>
#       <td>35.205.96.143</td>
#       <td>2023-01-13 19:14:49+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>BE</td>
#       <td>Python Requests</td>
#       <td>2.28</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>273234</th>
#       <td>35.205.96.143</td>
#       <td>2023-01-13 19:14:49+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>BE</td>
#       <td>Python Requests</td>
#       <td>2.28</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>273235</th>
#       <td>35.205.96.143</td>
#       <td>2023-01-13 19:14:49+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>BE</td>
#       <td>Python Requests</td>
#       <td>2.28</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>273236</th>
#       <td>35.205.96.143</td>
#       <td>2023-01-13 19:14:49+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>BE</td>
#       <td>Python Requests</td>
#       <td>2.28</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>273237</th>
#       <td>35.205.96.143</td>
#       <td>2023-01-13 19:14:49+00:00</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>BE</td>
#       <td>Python Requests</td>
#       <td>2.28</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>273287</th>
#       <td>66.23.225.248</td>
#       <td>2023-01-14 03:00:58+00:00</td>
#       <td>POST</td>
#       <td>/</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>81.0.4044</td>
#       <td>Linux</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr
# <strong>First 20 client errors for I Feel Love</strong>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>client_address</th>
#       <th>timestamp</th>
#       <th>method</th>
#       <th>path</th>
#       <th>query</th>
#       <th>fragment</th>
#       <th>protocol</th>
#       <th>status</th>
#       <th>size</th>
#       <th>referrer</th>
#       <th>...</th>
#       <th>client_country</th>
#       <th>agent_family</th>
#       <th>agent_version</th>
#       <th>os_family</th>
#       <th>os_version</th>
#       <th>device_family</th>
#       <th>device_brand</th>
#       <th>device_model</th>
#       <th>is_bot1</th>
#       <th>is_bot2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>268926</th>
#       <td>114.119.145.216</td>
#       <td>2023-01-02 08:34:10+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>SG</td>
#       <td>PetalBot</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Smartphone</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>269206</th>
#       <td>54.36.148.127</td>
#       <td>2023-01-03 15:35:51+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>FR</td>
#       <td>AhrefsBot</td>
#       <td>7.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>269224</th>
#       <td>54.36.148.124</td>
#       <td>2023-01-03 22:12:06+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>FR</td>
#       <td>AhrefsBot</td>
#       <td>7.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>269407</th>
#       <td>54.36.149.14</td>
#       <td>2023-01-04 07:32:36+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>FR</td>
#       <td>AhrefsBot</td>
#       <td>7.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>270427</th>
#       <td>77.75.79.31</td>
#       <td>2023-01-08 07:43:56+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>CZ</td>
#       <td>SeznamBot</td>
#       <td>4.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>271459</th>
#       <td>114.119.167.239</td>
#       <td>2023-01-10 08:16:32+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>SG</td>
#       <td>PetalBot</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Smartphone</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>273764</th>
#       <td>87.236.176.220</td>
#       <td>2023-01-16 18:35:06+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>421</td>
#       <td>322</td>
#       <td>http://obscenely.gay</td>
#       <td>...</td>
#       <td>GB</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>274328</th>
#       <td>114.119.155.54</td>
#       <td>2023-01-18 01:49:06+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>SG</td>
#       <td>PetalBot</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Smartphone</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>274369</th>
#       <td>159.223.50.5</td>
#       <td>2023-01-18 09:55:57+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>SG</td>
#       <td>Python Requests</td>
#       <td>2.27</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>274370</th>
#       <td>159.223.50.5</td>
#       <td>2023-01-18 09:55:58+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>SG</td>
#       <td>Python Requests</td>
#       <td>2.27</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>274371</th>
#       <td>159.223.50.5</td>
#       <td>2023-01-18 09:55:59+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>SG</td>
#       <td>Python Requests</td>
#       <td>2.27</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>274372</th>
#       <td>159.223.50.5</td>
#       <td>2023-01-18 09:56:01+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>SG</td>
#       <td>Python Requests</td>
#       <td>2.27</td>
#       <td>Other</td>
#       <td></td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>274503</th>
#       <td>77.75.79.31</td>
#       <td>2023-01-18 23:22:15+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>CZ</td>
#       <td>SeznamBot</td>
#       <td>4.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>274822</th>
#       <td>69.55.49.70</td>
#       <td>2023-01-20 08:30:40+00:00</td>
#       <td>GET</td>
#       <td>/blog/2019/i-feel-love</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>406</td>
#       <td>226</td>
#       <td>&lt;NA&gt;</
# <strong>First 20 client errors for Bely Display</strong>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>client_address</th>
#       <th>timestamp</th>
#       <th>method</th>
#       <th>path</th>
#       <th>query</th>
#       <th>fragment</th>
#       <th>protocol</th>
#       <th>status</th>
#       <th>size</th>
#       <th>referrer</th>
#       <th>...</th>
#       <th>client_country</th>
#       <th>agent_family</th>
#       <th>agent_version</th>
#       <th>os_family</th>
#       <th>os_version</th>
#       <th>device_family</th>
#       <th>device_brand</th>
#       <th>device_model</th>
#       <th>is_bot1</th>
#       <th>is_bot2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>268761</th>
#       <td>198.20.67.200</td>
#       <td>2023-01-01 10:49:47+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>SiteLockSpider</td>
#       <td></td>
#       <td>Windows</td>
#       <td>NT</td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269142</th>
#       <td>40.77.167.78</td>
#       <td>2023-01-03 09:58:27+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>403</td>
#       <td>1898</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>bingbot</td>
#       <td>2.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>269163</th>
#       <td>184.154.76.34</td>
#       <td>2023-01-03 10:49:03+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>http://www.google.com/url?url=apparebit.com&amp;ya...</td>
#       <td>...</td>
#       <td>US</td>
#       <td>IE</td>
#       <td>10.0</td>
#       <td>Windows</td>
#       <td>7</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269593</th>
#       <td>198.20.67.200</td>
#       <td>2023-01-05 02:27:43+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>http://www.google.com/url?url=apparebit.com&amp;ya...</td>
#       <td>...</td>
#       <td>US</td>
#       <td>IE</td>
#       <td>10.0</td>
#       <td>Windows</td>
#       <td>7</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269746</th>
#       <td>184.154.139.8</td>
#       <td>2023-01-05 10:46:18+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>SiteLockSpider</td>
#       <td></td>
#       <td>Windows</td>
#       <td>NT</td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>270262</th>
#       <td>184.154.76.34</td>
#       <td>2023-01-07 10:47:23+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>http://www.google.com/url?url=apparebit.com&amp;ya...</td>
#       <td>...</td>
#       <td>US</td>
#       <td>IE</td>
#       <td>10.0</td>
#       <td>Windows</td>
#       <td>7</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>270445</th>
#       <td>184.154.139.8</td>
#       <td>2023-01-08 10:46:02+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>http://www.google.com/url?url=apparebit.com&amp;ya...</td>
#       <td>...</td>
#       <td>US</td>
#       <td>IE</td>
#       <td>10.0</td>
#       <td>Windows</td>
#       <td>7</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>270852</th>
#       <td>198.20.67.200</td>
#       <td>2023-01-09 10:48:17+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>http://www.google.com/url?url=apparebit.com&amp;ya...</td>
#       <td>...</td>
#       <td>US</td>
#       <td>IE</td>
#       <td>10.0</td>
#       <td>Windows</td>
#       <td>7</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>271675</th>
#       <td>207.46.13.19</td>
#       <td>2023-01-11 03:08:13+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>403</td>
#       <td>1898</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>bingbot</td>
#       <td>2.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>271704</th>
#       <td>184.154.76.34</td>
#       <td>2023-01-11 10:53:53+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>SiteLockSpider</td>
#       <td></td>
#       <td>Windows</td>
#       <td>NT</td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>272957</th>
#       <td>207.46.13.19</td>
#       <td>2023-01-13 09:57:18+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>403</td>
#       <td>1898</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>bingbot</td>
#       <td>2.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>272977</th>
#       <td>184.154.139.5</td>
#       <td>2023-01-13 10:48:14+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>SiteLockSpider</td>
#       <td></td>
#       <td>Windows</td>
#       <td>NT</td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>273602</th>
#       <td>184.154.139.6</td>
#       <td>2023-01-15 10:47:21+00:00</td>
#       <td>GET</td>
#       <td>/assets/fonts/bely-display.woff2</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>403</td>
#       <td>4545</td>
#       <td>http://www.google.com/url?url=apparebit.com&amp;ya...</td>
#       <td>...</td>
#       <td>US</td>
#       <td>IE</td>
#       <td>10.0</td>
#       <td>Windows</td>
#       <td>7</td>
#       <td>Other</td>
# <strong>First 20 client errors for non-existent ads.txt</strong>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>client_address</th>
#       <th>timestamp</th>
#       <th>method</th>
#       <th>path</th>
#       <th>query</th>
#       <th>fragment</th>
#       <th>protocol</th>
#       <th>status</th>
#       <th>size</th>
#       <th>referrer</th>
#       <th>...</th>
#       <th>client_country</th>
#       <th>agent_family</th>
#       <th>agent_version</th>
#       <th>os_family</th>
#       <th>os_version</th>
#       <th>device_family</th>
#       <th>device_brand</th>
#       <th>device_model</th>
#       <th>is_bot1</th>
#       <th>is_bot2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>269413</th>
#       <td>34.133.88.216</td>
#       <td>2023-01-04 11:54:39+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>PhantomBot</td>
#       <td>1.0</td>
#       <td>Other</td>
#       <td></td>
#       <td>Spider</td>
#       <td>Spider</td>
#       <td>Desktop</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269484</th>
#       <td>23.229.104.2</td>
#       <td>2023-01-04 16:37:48+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>1.1</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>108.0.0</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269525</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:54+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>https://www.apparebit.com/ads.txt</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269526</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:54+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269527</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:54+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>http://apparebit.com/ads.txt</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269529</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:55+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>https://www.apparebit.com/ads.txt</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269531</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:56+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>https://www.apparebit.com/ads.txt</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269532</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:56+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269533</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:57+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>http://apparebit.com/ads.txt</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269535</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:57+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>https://www.apparebit.com/ads.txt</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269537</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:58+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>https://www.apparebit.com/ads.txt</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269538</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:58+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>&lt;NA&gt;</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269539</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:59+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>http://apparebit.com/ads.txt</td>
#       <td>...</td>
#       <td>US</td>
#       <td>Chrome</td>
#       <td>85.0.4183</td>
#       <td>Windows</td>
#       <td>10</td>
#       <td>Other</td>
#       <td></td>
#       <td></td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>269541</th>
#       <td>157.245.0.205</td>
#       <td>2023-01-04 23:00:59+00:00</td>
#       <td>GET</td>
#       <td>/ads.txt</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>2.0</td>
#       <td>404</td>
#       <td>1902</td>
#       <td>https://www.apparebit.com/ads.txt</td>
#       <td

# %% [markdown]
# Different paths are clearly associated with different user errors. Trying to
# access a non-existent page results in 404 NOT FOUND. But trying to access a font
# without the right headers results in 403 FORBIDDEN. The home page and "I Feel
# Love" see a lot of 406 NOT ACCEPTABLE errors. Since they all are caused by bots
# and scripts, it seems that people use very restrictive accept headers.
